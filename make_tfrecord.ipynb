# %%
import pandas as pd
sentences = pd.read_csv("sentences.csv", encoding='utf-8',index_col='index')

# %%
sentences.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119269 entries, 0 to 143968
# Data columns (total 1 columns):
# content    119261 non-null object
# dtypes: object(1)
# memory usage: 1.8+ MB

# %%
sentences
# Out:
#                              content
# index
# 0                               薄利汽配
# 1                       五菱荣光前外拉手颜色齐全
# 2                               80ml
# 3                        *小宅屋*专用盗图可耻
# 4                DERMATOLOGISTTESTED
# 5                         ─臉部·身體均通用─
# 6                  100%物理性防曬適合敏感肌膚使用
# 7                               温和全護
# 8                              輕透防曬乳
# 9                                露得清
# 10      http://xiaozhaiwu.taobao.com
# 11                             PA+++
# 12              broadspectrumuva·uvb
# 13                        PUreSCREEN
# 14                                TM
# 15                                 小
# 16                                 宅
# 17                                 屋
# 18                                50
# 19                                 +
# 20                                 S
# 21                                 P
# 22                                 F
# 23                                 ★
# ...

# %%
content = list(sentences["content"])

# %%
fuck = [len(str(x)) for x in content]
